# %% [markdown]
# # Bracket Model Notebook

# %% [markdown]
# Set `kaggle_dir` if you want the historical training pipeline to use Kaggle March Machine Learning Mania CSVs. The public Bart fetch path still works without Kaggle, but training and backtesting are stronger when those files are present.

# %%
from march_madness_2026_core import fit_or_load_models, get_current_team_table

# %%
kaggle_dir = None
cache_dir = 'cache'
matchup_model, score_model = fit_or_load_models(model_dir='artifacts/models', kaggle_dir=kaggle_dir, cache_dir=cache_dir, force=False)
team_table = get_current_team_table(year=2026, cache_dir=cache_dir)
matchup_model.get('metrics', {})
# Out:
# ---------------------------------------------------------------------------
# BadGzipFile                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39560\4137887902.py in <module>
#       2 cache_dir = 'cache'
#       3 matchup_model, score_model = fit_or_load_models(model_dir='artifacts/models', kaggle_dir=kaggle_dir, cache_dir=cache_dir, force=False)
# ----> 4 team_table = get_current_team_table(year=2026, cache_dir=cache_dir)
#       5 matchup_model.get('metrics', {})
#
# c:\Users\gordo\Documents\madness_2026\madness\march_madness_2026_core.py in get_current_team_table(year, cache_dir)
#     638
#     639 def get_current_team_table(year=2026, cache_dir="cache"):
# --> 640     return build_team_feature_table(year=year, cache_dir=cache_dir)
#     641
#     642 def team_lookup(feature_table):
#
# c:\Users\gordo\Documents\madness_2026\madness\march_madness_2026_core.py in build_team_feature_table(year, bracket, cache_dir, current_date)
#     232             team_list.append({"team": team, "team_norm": clean_team_name(team), "seed": seed, "region": region})
#     233     teams = pd.DataFrame(team_list)
# --> 234     base = load_bart_team_snapshot(year, snapshot_date=current_date, cache_dir=cache_dir)
#     235     try:
#     236         snapshot_7 = load_bart_team_snapshot(year, snapshot_date=current_date - dt.timedelta(days=7), cache_dir=cache_dir)[["team_norm", "barthag"]].rename(columns={"barthag": "barthag_7"})
#
# c:\Users\gordo\Documents\madness_2026\madness\march_madness_2026_core.py in load_bart_team_snapshot(year, snapshot_date, cache_dir)
#     151     cache_path = cache_dir / "bart" / "timemachine" / f"{stamp}_team_results.json.gz"
#     152     content = _fetch_bytes(url, cache_path=cache_path)
# --> 153     rows = json.loads(gzip.decompress(content).decode("utf-8"))
#     154     return _parse_bart_json_rows(rows)
#     155
#
# c:\Users\gordo\anaconda3\envs\roy\Lib\gzip.py in decompress(data)
#     605     while True:
#     606         fp = io.BytesIO(data)
# --> 607         if _read_gzip_header(fp) is None:
#     608             return b"".join(decompressed_members)
#     609         # Use a zlib raw deflate compressor
#
# c:\Users\gordo\anaconda3\envs\roy\Lib\gzip.py in _read_gzip_header(fp)
#     456
#     457     if magic != b'\037\213':
# --> 458         raise BadGzipFile('Not a gzipped file (%r)' % magic)
#     459
#     460     (method, flag, last_mtime) = struct.unpack("<BBIxx", _read_exact(fp, 8))
#
# BadGzipFile: Not a gzipped file (b'[[')

# %%
from march_madness_2026_core import simulate_full_bracket, bracket_probability_table
advancement, deterministic = simulate_full_bracket(team_table, matchup_model, n_sims=20000, gear=0, recent_form_weight=1.0, program_weight=1.0, upset_factor=0.0)
prob_table = bracket_probability_table(advancement)
prob_table.head(20), deterministic

# %% [markdown]
# Equivalent script: `01_bracket_model.py`
